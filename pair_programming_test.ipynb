# %% [markdown]
# # Pair Programming Feet and Inches to Meter Unit Conversion Tests

# %%
from pair_programming import feet_inches_to_meters

# %% [markdown]
# Test 1: 3 ft, 3 in -> 0.9906 m

# %%
print(feet_inches_to_meters(3, 3))
# Out:
# 0.9905999999999999

# %% [markdown]
# Test 2: 0 ft, 67 in -> 1.7018 m

# %%
print(feet_inches_to_meters(0, 67))
# Out:
# 1.7018
